# %%
start_lon=str(72.831353)
start_lat=str(18.968835)
end_lon=str(77.166284)
end_lat=str(28.677697)

# %%
import requests
r = requests.get('http://0.0.0.0:5000/route/v1/driving/'+start_lon+','+start_lat+';'+end_lon+','+end_lat+'?alternatives=3&overview=false&steps=true')
route_data=r.json()

# %%
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    return c * r

# %%
num_routes=len(route_data['routes'])
route_data['routes'][0]['legs'][0]['steps']
# Out:
# [{'intersections': [{'out': 0,
#     'entry': [True],
#     'bearings': [93],
#     'location': [72.831543, 18.968354]},
#    {'out': 0,
#     'location': [72.831757, 18.968342],
#     'bearings': [90, 180, 270],
#     'entry': [True, True, False],
#     'in': 2}],
#   'driving_side': 'right',
#   'geometry': 'ewwrBc|o{L@k@MsD',
#   'mode': 'driving',
#   'duration': 22.2,
#   'maneuver': {'bearing_after': 93,
#    'type': 'depart',
#    'modifier': 'left',
#    'bearing_before': 0,
#    'location': [72.831543, 18.968354]},
#   'weight': 22.2,
#   'distance': 117.9,
#   'name': ''},
#  {'intersections': [{'out': 0,
#     'location': [72.832661, 18.968407],
#     'bearings': [0, 180, 270],
#     'entry': [True, False, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.832625, 18.968891],
#     'bearings': [0, 180, 345],
#     'entry': [True, False, True],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'qwwrBccp{L_BDcINm@@',
#   'mode': 'driving',
#   'duration': 14.4,
#   'maneuver': {'bearing_after': 355,
#    'type': 'end of road',
#    'modifier': 'left',
#    'bearing_before': 84,
#    'location': [72.832661, 18.968407]},
#   'weight': 14.4,
#   'distance': 259.7,
#   'name': 'Sir Jamshetji Jeejeebhoy Road'},
#  {'intersections': [{'out': 0,
#     'location': [72.832543, 18.970739],
#     'bearings': [0, 180, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.83373, 18.974083],
#     'bearings': [15, 120, 195, 285],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 2,
#     'location': [72.833564, 18.975466],
#     'bearings': [75, 165, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.833483, 18.975951],
#     'bearings': [0, 165, 195],
#     'entry': [True, False, True],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'cfxrBkbp{LaAEwCCy@M}@_@mAeAqAw@k@O}Bg@c@Es@BgAFuBZ_BNW@i@BS@aA@gAKe@Io@IeEa@',
#   'mode': 'driving',
#   'duration': 38.1,
#   'maneuver': {'bearing_after': 1,
#    'type': 'fork',
#    'modifier': 'slight right',
#    'bearing_before': 357,
#    'location': [72.832543, 18.970739]},
#   'weight': 38.1,
#   'distance': 900.1,
#   'name': 'Dr Baba Saheb Ambedkar Marg (Victoria Garden Road)'},
#  {'intersections': [{'out': 1,
#     'location': [72.833755, 18.978492],
#     'bearings': [0, 15, 195],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.833847, 18.978794],
#     'bearings': [15, 195],
#     'entry': [True, False],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'qvyrB_jp{L{@QgIoAuB[uEgAcFeAcBYoBUkCQePaAqBIaCAyCH{BN_AFg@?s@Ko@YmCwAm@Q{@G{Ja@wCIiAMiBa@{Aq@cBs@_AYmAC}A?sBAoAOu@@',
#   'mode': 'driving',
#   'duration': 101.6,
#   'maneuver': {'bearing_after': 15,
#    'type': 'fork',
#    'modifier': 'slight right',
#    'bearing_before': 8,
#    'location': [72.833755, 18.978492]},
#   'weight': 101.6,
#   'distance': 2406.9,
#   'name': 'Lalbaug Flyover'},
#  {'intersections': [{'out': 0,
#     'location': [72.837605, 18.999555],
#     'bearings': [15, 180, 210],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.838686, 19.003587],
#     'bearings': [15, 195, 285],
#     'entry': [True, False, True],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'gz}rBabq{L}Di@aB[UGsA[sA[cBWaC[aB]s@O',
#   'mode': 'driving',
#   'duration': 20.9,
#   'maneuver': {'bearing_after': 11,
#    'type': 'merge',
#    'modifier': 'slight left',
#    'bearing_before': 357,
#    'location': [72.837605, 18.999555]},
#   'weight': 20.9,
#   'distance': 493.8,
#   'name': 'Dr Babasaheb Ambedkar Marg (Vincent Road)'},
#  {'intersections': [{'out': 1,
#     'location': [72.838768, 19.003853],
#     'bearings': [0, 15, 195],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.838881, 19.004114],
#     'bearings': [15, 195],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.840796, 19.006947],
#     'bearings': [30, 210],
#     'entry': [True, False],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'au~rBiiq{Ls@Uy@Os@Uq@[s@k@oAqAc@_@w@g@gAs@o@[_Ag@]M',
#   'mode': 'driving',
#   'duration': 18.1,
#   'maneuver': {'bearing_after': 21,
#    'type': 'fork',
#    'modifier': 'slight right',
#    'bearing_before': 15,
#    'location': [72.838768, 19.003853]},
#   'weight': 18.1,
#   'distance': 428.2,
#   'name': 'Hindmata Flyover'},
#  {'intersections': [{'out': 0,
#     'location': [72.840871, 19.007101],
#     'bearings': [15, 30, 210],
#     'entry': [True, True, False],
#     'in': 2}],
#   'driving_side': 'right',
#   'geometry': 'ki_sBmvq{Ly@I',
#   'mode': 'driving',
#   'duration': 3,
#   'maneuver': {'bearing_after': 8,
#    'type': 'off ramp',
#    'modifier': 'straight',
#    'bearing_before': 23,
#    'location': [72.840871, 19.007101]},
#   'weight': 3,
#   'distance': 33,
#   'name': ''},
#  {'intersections': [{'out': 0,
#     'location': [72.840924, 19.007393],
#     'bearings': [30, 195, 210],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.84182, 19.009517],
#     'bearings': [30, 120, 210, 300],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 0,
#     'location': [72.841899, 19.009644],
#     'bearings': [30, 120, 210],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.842422, 19.010456],
#     'bearings': [30, 120, 210],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.843088, 19.011362],
#     'bearings': [30, 210, 225],
#     'entry': [True, False, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.843574, 19.012083],
#     'bearings': [30, 210, 255],
#     'entry': [True, False, True],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'ek_sBwvq{Lc@QiAWwA]mA_@QEw@YEAeAi@WOaB}@aAi@u@a@gAq@u@q@oC_BeDoB',
#   'mode': 'driving',
#   'duration': 35.8,
#   'maneuver': {'bearing_after': 23,
#    'type': 'merge',
#    'modifier': 'slight left',
#    'bearing_before': 8,
#    'location': [72.840924, 19.007393]},
#   'weight': 35.8,
#   'distance': 703.9,
#   'name': 'Dr Babasaheb Ambedkar Marg (Vincent Road)'},
#  {'intersections': [{'out': 0,
#     'location': [72.844129, 19.012906],
#     'bearings': [27, 37, 213],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.844475, 19.01349],
#     'bearings': [30, 210, 300],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.84534, 19.014779],
#     'bearings': [30, 120, 210],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.846527, 19.016381],
#     'bearings': [30, 135, 210, 300],
#     'entry': [True, True, False, True],
#     'in': 2}],
#   'driving_side': 'right',
#   'geometry': 'um`sByjr{LeAe@m@_@s@a@g@YeDoBuCmB_@WgBmAQMOKiCeBAAuA{@KGQC',
#   'mode': 'driving',
#   'duration': 31.1,
#   'maneuver': {'bearing_after': 26,
#    'type': 'fork',
#    'modifier': 'slight left',
#    'bearing_before': 32,
#    'location': [72.844129, 19.012906]},
#   'weight': 31.1,
#   'distance': 632.1,
#   'name': 'Dr Babasaheb Ambedkar Marg (Vincent Road)'},
#  {'intersections': [{'out': 2,
#     'location': [72.84741, 19.017656],
#     'bearings': [150, 210, 345],
#     'entry': [False, False, True],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'kkasBi_s{LQBS?SE',
#   'mode': 'driving',
#   'rotary_name': 'Khodadad Circle',
#   'duration': 2.8,
#   'maneuver': {'exit': 1,
#    'bearing_after': 343,
#    'type': 'rotary',
#    'modifier': 'left',
#    'bearing_before': 26,
#    'location': [72.84741, 19.017656]},
#   'weight': 2.8,
#   'distance': 33.5,
#   'name': 'Tilak Road'},
#  {'intersections': [{'out': 2,
#     'location': [72.847422, 19.01795],
#     'bearings': [30, 195, 315],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.846853, 19.018389],
#     'bearings': [120, 210, 300],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 1,
#     'location': [72.845589, 19.019223],
#     'bearings': [120, 300],
#     'entry': [False, True],
#     'in': 0},
#    {'out': 1,
#     'location': [72.843279, 19.020714],
#     'bearings': [120, 300],
#     'entry': [False, True],
#     'in': 0}],
#   'driving_side': 'right',
#   'geometry': 'emasBk_s{L_@Zw@tAeDzFiHlM]n@ELIRKd@',
#   'mode': 'driving',
#   'duration': 33.4,
#   'maneuver': {'exit': 1,
#    'bearing_after': 317,
#    'type': 'exit rotary',
#    'modifier': 'left',
#    'bearing_before': 16,
#    'location': [72.847422, 19.01795]},
#   'weight': 33.4,
#   'distance': 604.5,
#   'name': 'Tilak Road'},
#  {'intersections': [{'out': 2,
#     'location': [72.842682, 19.020996],
#     'bearings': [75, 105, 270],
#     'entry': [False, False, True],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'g`bsBwar{LATCpA',
#   'mode': 'driving',
#   'duration': 3.1,
#   'maneuver': {'bearing_after': 272,
#    'type': 'turn',
#    'modifier': 'straight',
#    'bearing_before': 288,
#    'location': [72.842682, 19.020996]},
#   'weight': 3.1,
#   'distance': 55.5,
#   'name': 'N C Kelkar Marg'},
#  {'intersections': [{'out': 2,
#     'location': [72.842156, 19.02103],
#     'bearings': [90, 255, 285],
#     'entry': [False, True, True],
#     'in': 0}],
#   'driving_side': 'right',
#   'geometry': 'm`bsBo~q{LGXIJK@M?',
#   'mode': 'driving',
#   'duration': 2,
#   'maneuver': {'bearing_after': 288,
#    'type': 'fork',
#    'modifier': 'slight right',
#    'bearing_before': 272,
#    'location': [72.842156, 19.02103]},
#   'weight': 2,
#   'distance': 37,
#   'name': ''},
#  {'intersections': [{'out': 0,
#     'location': [72.841964, 19.021252],
#     'bearings': [45, 180, 225],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.84219, 19.021526],
#     'bearings': [30, 225, 300],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.842307, 19.0217],
#     'bearings': [30, 60, 210],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 2,
#     'location': [72.842403, 19.022783],
#     'bearings': [75, 165, 330],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 3,
#     'location': [72.841891, 19.023299],
#     'bearings': [30, 120, 210, 300],
#     'entry': [True, False, True, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.841232, 19.023722],
#     'bearings': [120, 195, 330],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.840908, 19.024291],
#     'bearings': [150, 225, 330],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.840757, 19.024558],
#     'bearings': [150, 225, 330],
#     'entry': [False, True, True],
#     'in': 0}],
#   'driving_side': 'right',
#   'geometry': 'yabsBg}q{Lw@m@a@Wa@UWG_@C_A?}@Ne@Pa@`@_@p@sAbCqB~@u@\\cBx@',
#   'mode': 'driving',
#   'duration': 28.8,
#   'maneuver': {'bearing_after': 36,
#    'type': 'turn',
#    'modifier': 'slight right',
#    'bearing_before': 4,
#    'location': [72.841964, 19.021252]},
#   'weight': 28.8,
#   'distance': 520,
#   'name': 'N C Kelkar Marg'},
#  {'intersections': [{'out': 3,
#     'location': [72.840474, 19.025056],
#     'bearings': [30, 150, 225, 330],
#     'entry': [False, False, True, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.840428, 19.025136],
#     'bearings': [31, 151, 218, 231, 309],
#     'entry': [True, False, False, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.840476, 19.025212],
#     'bearings': [30, 150, 210],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.840641, 19.025475],
#     'bearings': [30, 210, 255],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.840945, 19.026579],
#     'bearings': [15, 105, 195],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.841369, 19.028566],
#     'bearings': [15, 105, 195, 255, 300],
#     'entry': [True, True, False, True, True],
#     'in': 2},
#    {'out': 0,
#     'location': [72.841584, 19.029569],
#     'bearings': [15, 195, 300],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.841675, 19.029999],
#     'bearings': [15, 105, 195],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.842002, 19.031533],
#     'bearings': [0, 105, 195, 285],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 0,
#     'location': [72.842083, 19.032511],
#     'bearings': [0, 105, 180],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.842139, 19.033188],
#     'bearings': [0, 75, 180, 270],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 0,
#     'location': [72.842225, 19.034236],
#     'bearings': [0, 75, 180, 270],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 0,
#     'location': [72.842321, 19.035401],
#     'bearings': [0, 90, 180, 270],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 3,
#     'location': [72.84225, 19.037016],
#     'bearings': [90, 180, 270, 345],
#     'entry': [True, False, True, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.842003, 19.038462],
#     'bearings': [75, 165, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.841951, 19.038637],
#     'bearings': [165, 270, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.841871, 19.038921],
#     'bearings': [75, 165, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 3,
#     'location': [72.841447, 19.040008],
#     'bearings': [75, 165, 255, 330],
#     'entry': [True, False, True, True],
#     'in': 1},
#    {'out': 3,
#     'location': [72.841116, 19.040686],
#     'bearings': [60, 150, 255, 330],
#     'entry': [True, False, True, True],
#     'in': 1},
#    {'out': 3,
#     'location': [72.84048, 19.041962],
#     'bearings': [150, 180, 285, 330],
#     'entry': [False, True, True, True],
#     'in': 0},
#    {'out': 3,
#     'location': [72.840053, 19.04282],
#     'bearings': [60, 150, 180, 330],
#     'entry': [True, False, True, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.838248, 19.047728],
#     'bearings': [0, 180],
#     'entry': [True, False],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'sybsB}sq{LOFMIu@_@_@U{Dg@{G{@qBWgEi@uAS_CYqDe@cEOgCKqEQgFQcIL_Hp@c@Hw@NyErAgC`A}F~BkDtAo@TyDzA{JxDgA`@aBXeE?}C@',
#   'mode': 'driving',
#   'duration': 152.7,
#   'maneuver': {'bearing_after': 330,
#    'type': 'turn',
#    'modifier': 'right',
#    'bearing_before': 330,
#    'location': [72.840474, 19.025056]},
#   'weight': 152.7,
#   'distance': 2720,
#   'name': 'Lady Jamshedji Road'},
#  {'intersections': [{'out': 0,
#     'location': [72.838235, 19.048522],
#     'bearings': [0, 180],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.838233, 19.048679],
#     'bearings': [0, 180, 345],
#     'entry': [True, False, True],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'glgsB_fq{L_@@_H@',
#   'mode': 'driving',
#   'duration': 12.5,
#   'maneuver': {'bearing_after': 358,
#    'type': 'new name',
#    'modifier': 'straight',
#    'bearing_before': 358,
#    'location': [72.838235, 19.048522]},
#   'weight': 12.5,
#   'distance': 177.2,
#   'name': 'Swami Vivekanand Road'},
#  {'intersections': [{'out': 1,
#     'location': [72.838221, 19.050115],
#     'bearings': [0, 75, 180, 255],
#     'entry': [True, True, False, False],
#     'in': 2},
#    {'out': 1,
#     'location': [72.838336, 19.050153],
#     'bearings': [0, 75, 180, 255],
#     'entry': [False, True, True, False],
#     'in': 3}],
#   'driving_side': 'right',
#   'geometry': 'gvgsB{eq{LEWMc@g@aB',
#   'mode': 'driving',
#   'duration': 7.8,
#   'maneuver': {'bearing_after': 70,
#    'type': 'turn',
#    'modifier': 'right',
#    'bearing_before': 358,
#    'location': [72.838221, 19.050115]},
#   'weight': 7.8,
#   'distance': 89.4,
#   'name': ''},
#  {'intersections': [{'classes': ['motorway'],
#     'out': 0,
#     'location': [72.839006, 19.050423],
#     'bearings': [75, 240, 270],
#     'entry': [True, False, False],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'cxgsByjq{L{AwFIcA',
#   'mode': 'driving',
#   'duration': 14.1,
#   'maneuver': {'bearing_after': 68,
#    'type': 'on ramp',
#    'modifier': 'straight',
#    'bearing_before': 66,
#    'location': [72.839006, 19.050423]},
#   'weight': 14.1,
#   'distance': 176.2,
#   'name': ''},
#  {'intersections': [{'classes': ['motorway'],
#     'out': 0,
#     'location': [72.840589, 19.050925],
#     'bearings': [60, 240, 255],
#     'entry': [True, False, False],
#     'in': 2},
#    {'classes': ['motorway'],
#     'out': 1,
#     'location': [72.84351, 19.052116],
#     'bearings': [60, 75, 240],
#     'entry': [True, True, False],
#     'in': 2},
#    {'classes': ['motorway'],
#     'out': 0,
#     'location': [72.846459, 19.05757],
#     'bearings': [0, 180],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.846443, 19.057975],
#     'bearings': [0, 180, 195],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.846452, 19.058459],
#     'bearings': [0, 180, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.846529, 19.063671],
#     'bearings': [0, 180, 195],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.84667, 19.071335],
#     'bearings': [0, 180, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.846845, 19.080449],
#     'bearings': [90, 180, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.846065, 19.084355],
#     'bearings': [165, 195, 345],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 1,
#     'location': [72.849699, 19.092765],
#     'bearings': [56, 66, 251],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.853912, 19.09922],
#     'bearings': [15, 30, 195],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.854002, 19.099571],
#     'bearings': [15, 195, 210],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 2,
#     'location': [72.853698, 19.105523],
#     'bearings': [165, 330, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.855711, 19.120214],
#     'bearings': [12, 189, 198],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.855073, 19.133224],
#     'bearings': [0, 180, 270],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.854915, 19.137722],
#     'bearings': [0, 180, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.85631, 19.149824],
#     'bearings': [0, 180, 255],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.856344, 19.150317],
#     'bearings': [0, 180, 330],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.857707, 19.160478],
#     'bearings': [6, 188, 205, 355],
#     'entry': [True, False, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.858927, 19.17025],
#     'bearings': [15, 195, 210],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.858947, 19.170389],
#     'bearings': [0, 195, 330],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.858666, 19.177064],
#     'bearings': [158, 171, 344],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.858348, 19.181121],
#     'bearings': [0, 180, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.858359, 19.184211],
#     'bearings': [0, 180, 195],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.858368, 19.185497],
#     'bearings': [0, 180, 210],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.858333, 19.189494],
#     'bearings': [0, 180, 330],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.859635, 19.19387],
#     'bearings': [30, 210, 225],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.860903, 19.199499],
#     'bearings': [15, 195, 330],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.862935, 19.203292],
#     'bearings': [45, 225, 240],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 1,
#     'location': [72.863118, 19.203475],
#     'bearings': [30, 45, 225],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.86791, 19.208987],
#     'bearings': [15, 210, 225],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.868395, 19.211238],
#     'bearings': [0, 180, 330],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.866854, 19.216889],
#     'bearings': [165, 180, 345],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.866693, 19.217393],
#     'bearings': [165, 315, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.863942, 19.225335],
#     'bearings': [165, 180, 345],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.863291, 19.22747],
#     'bearings': [0, 180, 270],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.863289, 19.227571],
#     'bearings': [0, 180, 330],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.863291, 19.236797],
#     'bearings': [15, 180, 210],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.863925, 19.240901],
#     'bearings': [15, 195, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.864813, 19.246977],
#     'bearings': [0, 180, 210],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 1,
#     'location': [72.865177, 19.248156],
#     'bearings': [8, 20, 199],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.865533, 19.248892],
#     'bearings': [30, 210],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.867833, 19.252169],
#     'bearings': [30, 210],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.868057, 19.25249],
#     'bearings': [30, 210, 225],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 1,
#     'location': [72.868834, 19.253643],
#     'bearings': [26, 32, 213],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.870986, 19.256784],
#     'bearings': [30, 210, 240],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.871855, 19.258648],
#     'bearings': [15, 120, 195],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.872945, 19.261153],
#     'bearings': [30, 195, 300],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.873086, 19.261425],
#     'bearings': [30, 105, 210, 300],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 0,
#     'location': [72.875101, 19.264767],
#     'bearings': [30, 120, 225, 300],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 0,
#     'location': [72.876712, 19.266836],
#     'bearings': [30, 120, 210, 315],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 0,
#     'location': [72.888454, 19.275993],
#     'bearings': [60, 240, 270],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.890428, 19.277878],
#     'bearings': [30, 120, 210, 300],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 0,
#     'location': [72.891105, 19.279535],
#     'bearings': [15, 195, 225],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.904305, 19.28539],
#     'bearings': [30, 135, 225, 345],
#     'entry': [True, True, False, True],
#     'in': 2}],
#   'driving_side': 'right',
#   'geometry': 'i{gsButq{LmAyD{@uCcBwFcA{DUw@_@y@[e@]g@UYSQk@a@i@Ys@]a@O{@Ua@Kg@Ic@GYAa@C{@?cA?qIAqAB_BAyAAyYK}AA}n@[uBAyHAsKMuKIs@?s@Ag@?kBC{FGw@BS@]DcBPcFl@yEl@}@Lm@FaBPWFiAXs@P_A`@k@\\}@p@mDtC]XuAfAiAj@{@ViAR]Da@Fm@Bm@?iAI}@Os@S[KMEICk@[a@Ws@i@a@e@a@i@q@uASe@K_@[_B[iCi@aFc@yD]eCWcACOUs@So@Sg@m@iA_AoAgAkAeA}@wAy@uAi@uAc@eAWmBc@uFwAeFyAw@SeAQgBk@uBc@mBS}@CmAByANsEj@_LbBm@HsANeANmANk@Fs@?{@Aq@GeAMoYaE_I_A}[eCaHs@wPcCeBWs@Au@AoAHo@HoA^yAp@mBhAo@V]NkAVmAHoUNqMTgINiLJqC@}FNuINmAAmAK}@Oo@MkN}CkASk@Ik@E}H]qHQeCMcCIK?cBEk@E{Ki@sBKiDOaDYuFe@uPuAi@E}AM_DWSCyCQiBQsCQsCSgCSqCSqCS_CMk@EeBKyBOyBKkBK{BMkCKoAK[CQAeCO{AGaDQwCQ_COkACeA?o@BaAHs@FoB`@cB\\aAZy@ViATuARq@HaABuC@gDBqCBy@AM?i@AU?uC?oC@qCAqB?Q?aDAmA?]?gCBaDBgB@aA@aFAiAAe@AeAAcC?cA?u@CiAU_@M]Ma@UeAg@kBy@}B}@g@UQIMEGEi@My@O{Ca@gDc@_C[kCYcD_@qBUsBUoAQiAKa@GeAO_AW}@[k@Sq@c@k@]g@]c@a@_A{@a@]}@}@e@c@IKqAsAmAkA}AaBqCmCgBaBw@u@yA{AuAoA_Aq@q@c@u@g@sAm@gBq@w@SmBg@_AOuAOgBE]?kA?}ADoAJmANsATiB`@eB`@_Cn@}Bl@o@NoEjAcB^uAZYHoDz@kEdAeCl@eCl@_B`@iBb@oAZiBd@oCn@sAZ}A`@o@Pm@NYHa@Jq@R{@Vs@Ta@Lg@J{@Lg@D]BG@Q?G?K?eA?cA?uA?}C?eFA_BAwF@gCBaCBwBDqEDY?w@?{@Am@Cu@Gs@C{@ImDWeE_@yD]yD[OC}AM_DYgBQgDW}BS_BMuBOmCQiCQeAG[Cy@M{@SkA]ME]K_@Iq@Ya@Uw@i@kAu@}B_BoBkAaAk@{EsC_Am@s@_@qDyBqBmAo@a@]SIE{EyCo@_@uBqAg@Y}@]kBq@mCaA}@[eCw@iC_AoDiAs@Ww@[c@QyBq@}B}@qAm@cAi@}AaAoB_B[UaAs@aFuDyBwAsCeBgBoAuBwAuB_BwAyAgAoBaAcBcAeBgAsBiDiFKOs@gAsAqBcAwA{@yAmAuBiA{B{DiHaB_Do@mAWe@S_@MSs@sA_@k@[c@aAaAkAaAECgBkAKG_@Si@YaBi@gAUm@K]E}AQmCYeC_@_Dc@eD]}C]eCYoAKsACmADwAH]A]EUK[SW]U_@Ga@Ca@BgABy@Fu@Hg@FYv@iBz@aBVw@N{@@_@@cACeDDcADo@Hc@z@iErAqGx@yDp@wCH_AAmAQsBe@yAi@y@a@g@WWs@_@eA[s@KwCY',
#   'mode': 'driving',
#   'duration': 1306.5,
#   'maneuver': {'bearing_after': 64,
#    'type': 'merge',
#    'modifier': 'slight right',
#    'bearing_before': 80,
#    'location': [72.840589, 19.050925]},
#   'ref': 'NH8',
#   'weight': 1306.5,
#   'distance': 30401.9,
#   'name': 'Western Express Highway'},
#  {'intersections': [{'out': 0,
#     'location': [72.904804, 19.287019],
#     'bearings': [0, 195],
#     'entry': [True, False],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': '{~utB_f~{L}^{A',
#   'mode': 'driving',
#   'duration': 24.2,
#   'maneuver': {'bearing_after': 4,
#    'type': 'new name',
#    'modifier': 'straight',
#    'bearing_before': 8,
#    'location': [72.904804, 19.287019]},
#   'ref': 'NH48',
#   'weight': 24.2,
#   'distance': 571,
#   'name': 'Vasai Creek Bridge'},
#  {'intersections': [{'out': 0,
#     'location': [72.905262, 19.292134],
#     'bearings': [0, 180],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 2,
#     'location': [72.906284, 19.298681],
#     'bearings': [165, 255, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.899637, 19.31464],
#     'bearings': [0, 180, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.896135, 19.320323],
#     'bearings': [135, 150, 330],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.893629, 19.328004],
#     'bearings': [30, 195, 300],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.894221, 19.329315],
#     'bearings': [30, 120, 210],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.895529, 19.332208],
#     'bearings': [15, 210, 285],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.891396, 19.344185],
#     'bearings': [0, 180, 270],
#     'entry': [True, False, True],
#     'in': 1},
#    {'classes': ['tunnel'],
#     'out': 0,
#     'location': [72.893507, 19.350852],
#     'bearings': [15, 195],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.893619, 19.351196],
#     'bearings': [15, 195],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.893909, 19.36617],
#     'bearings': [15, 105, 195, 270],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 0,
#     'location': [72.895476, 19.378487],
#     'bearings': [0, 180, 285],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.895477, 19.379439],
#     'bearings': [0, 180, 285],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.89549, 19.380088],
#     'bearings': [6, 181, 355],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.897574, 19.385827],
#     'bearings': [0, 180, 195],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 2,
#     'location': [72.883007, 19.402907],
#     'bearings': [165, 315, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 3,
#     'location': [72.882954, 19.40305],
#     'bearings': [75, 165, 270, 345],
#     'entry': [True, False, True, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.879747, 19.407718],
#     'bearings': [120, 210, 300],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.878902, 19.408304],
#     'bearings': [135, 300, 315],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.876604, 19.412959],
#     'bearings': [159, 172, 336],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 3,
#     'location': [72.876542, 19.413092],
#     'bearings': [75, 150, 255, 345],
#     'entry': [True, False, True, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.875925, 19.414562],
#     'bearings': [165, 255, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.875397, 19.415895],
#     'bearings': [165, 255, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.874766, 19.418033],
#     'bearings': [0, 180, 255],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.873978, 19.426078],
#     'bearings': [150, 255, 330],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.873502, 19.4269],
#     'bearings': [150, 315, 330],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.873856, 19.432892],
#     'bearings': [45, 225, 255],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.87484, 19.43383],
#     'bearings': [45, 225, 315],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 1,
#     'location': [72.876875, 19.437107],
#     'bearings': [15, 30, 210],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.879379, 19.4418],
#     'bearings': [28, 208, 217],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.880069, 19.442887],
#     'bearings': [30, 210, 300],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.880426, 19.443476],
#     'bearings': [30, 210, 285],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.8814, 19.445047],
#     'bearings': [30, 210, 270],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.882856, 19.44798],
#     'bearings': [15, 195, 285],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.883501, 19.450736],
#     'bearings': [15, 195, 270],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.884524, 19.45594],
#     'bearings': [15, 195, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.885127, 19.458397],
#     'bearings': [15, 195, 285],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.885416, 19.459435],
#     'bearings': [15, 195, 285],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 1,
#     'location': [72.885522, 19.459727],
#     'bearings': [0, 15, 195],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [72.887133, 19.466056],
#     'bearings': [0, 30, 210],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.890727, 19.470083],
#     'bearings': [38, 233, 239],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.891417, 19.470921],
#     'bearings': [30, 45, 225],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.894026, 19.476661],
#     'bearings': [15, 195, 225],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.894735, 19.478373],
#     'bearings': [30, 210, 285],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 1,
#     'location': [72.895159, 19.479013],
#     'bearings': [15, 45, 210],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [72.897117, 19.481374],
#     'bearings': [15, 45, 225],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.899241, 19.48396],
#     'bearings': [45, 210, 240],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 1,
#     'location': [72.90317, 19.487606],
#     'bearings': [15, 45, 225],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.906488, 19.491066],
#     'bearings': [30, 210, 240],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 1,
#     'location': [72.90667, 19.49133],
#     'bearings': [25, 33, 213],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.909145, 19.494708],
#     'bearings': [45, 225, 255],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.913552, 19.496514],
#     'bearings': [60, 240, 270],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.915095, 19.497393],
#     'bearings': [60, 240, 330],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 1,
#     'location': [72.917598, 19.499701],
#     'bearings': [30, 45, 225],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 2,
#     'location': [72.917922, 19.504284],
#     'bearings': [165, 210, 345],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.916686, 19.530278],
#     'bearings': [0, 180, 270],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.916039, 19.542957],
#     'bearings': [166, 338, 346],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.914769, 19.547656],
#     'bearings': [165, 210, 345],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.914864, 19.612355],
#     'bearings': [0, 180, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.913821, 19.616921],
#     'bearings': [150, 165, 330],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.911122, 19.6209],
#     'bearings': [150, 315, 330],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.910365, 19.624857],
#     'bearings': [30, 210, 225],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.915005, 19.63067],
#     'bearings': [15, 195, 270],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.906406, 19.658564],
#     'bearings': [0, 75, 180, 255],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 0,
#     'location': [72.906148, 19.667831],
#     'bearings': [0, 180, 300],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 1,
#     'location': [72.922633, 19.708188],
#     'bearings': [60, 75, 255],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.92491, 19.708703],
#     'bearings': [75, 255, 270],
#     'entry': [True, False, False],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'y~vtB{h~{LsFYo@Au@?a@Ac@AiAEc@EgAKaAWuCw@oCs@wB]y@Ck@AcAD}@Ls@H]JcAZw@\\aAd@kAp@wBlAsC~AaDfBqH|DaRbK{Bx@iBh@yBh@uG`A_HbAuC^oBHiB@sEO}CI}ABs@Du@Dq@L]HSHeA`@uAv@cAt@iAjAo@x@]d@[`@s@bAuAhBaAfAe@`@_@\\_Ab@}B`AwDbA{Cv@w@XcFzBkElBu@VeARiANmAFq@CsAGuA]UIgGuBaQeG}Bi@eAOoAIqAByAJy@TcA^aAb@gAr@sCnBmAv@{@d@SHk@T_Dz@cCp@iWrHyCv@}@Ro@BaAD}ACeAKgAWkBi@mDcAkVuGeAU_C_@kAKkAEuBRaMhC}BZuD\\c^l@uCOoC[cAU{@YcLqDuL{D}EyAiC]cBGwCE}a@FgH?}D?aCAaCM{@KmA[yCuAiAq@mBiAkAs@qBo@kAQsBY_DG}AHeBRsBl@eClAkA|@gA~@q[zYmBfCmCpEmFxIiEbHaCxDiB~C_A|@}@l@mAp@iCx@{Ad@{FzAuBf@cB^kAV[JkHxAeDv@kAf@kAp@oAdAcAjAgD`Go@zAcAlAw@|@k@^oBbAkA`@sA`@mA^}M`ECBYJcEpAaBf@uAd@uDbAwHnBqBLiAAcAK[C_@I_AQuB]kCg@aCQqBC_DD{ANeANwAZwBp@uB`AuBdAkAj@oB~@s@^}@b@{H|DiAZeAR}@Hq@@o@AoAOg@Kw@U]OaAo@oAiA_AaAm@i@u@{@oCyCk@i@a@a@w@q@oAw@uAs@oKwEwB_AsH}CmGmCoFgCc@SmBiAgAk@uBgAaCqAwDoBcFqCaD{AeB_@}AUeAMyCi@gIgAqQqBeFi@wEo@kNyBIAsDs@QCy@Si@OaBk@aFuBkAc@mAWs@IsBCuGHoAE}AWq@OkAa@qAe@uAi@eBy@iDmDeIgJOMUa@gDiCgAy@g@a@oEqCkBs@gDy@q@MqBc@mAYyFoA{@QoB_@aCo@cB}@eAe@y@m@yBgB}I_HWS]UiG}EeE_DeCmBiBmB}BgCkJmLsFaHeAwAw@w@_@_@cAy@iE}BSMs@c@eEgCiCaB{BwAaAm@i@]g@]i@k@YWQOe@_A[{@[wAYuAMaAYsBOw@U_Ay@sBs@sAa@_AmAiCmAeCSe@aAiBm@aAm@s@s@m@_DqCsAkAGG_Ay@{@g@}@YwAWw@Ku@AcA@{@NsKnAw@HiGr@{DZuCRs@Fy@BoAAqACcF[aDMmAA}@BiAPoB`@iCr@m@LcALeCJuBE_NC{H?S?mGHq@@kNP{MNaFHkEDsCD}@CyAEuEUgBIqDSiIg@uIc@oH]iAEy@CwA@yANqBZ_F|@{Ex@kB\\mHnAqU~DyE|@yE|@kGfAaDl@eAPcCPeDHo]McTKsGCyBCkBIqAK}AQsCg@wCi@o\\qGeNoCeFcAyDo@sAIuAD{ARkAXiCdAmDzAkCbAqA`@sAR_DZuLfA_]hDyBb@{A^_EvA_DdAeBb@eAPwAH{ABuBQmBSaCa@wAe@oDwAkBw@iAa@u@Os@?i@BuAX}@f@wAv@oB`AuAf@_AReAFgACiAKcAS{GeC}EiBmBq@oA]iAWaBOy@EqAEuUB_PBmL@iAFeAPs@PiA^w@XiAn@qAv@{WzO_DjBoAn@cA\\s@R{@Hy@BeAA{@KgAS{@Ks@WkAc@qAw@qD}C}DcEeEiEyAkAyAgAeAs@}@c@aAW{@SC?gAMeBEua@Wi\\McBBiADcALs@Lw@Ro@Vw@b@q@f@qBdBqFzEgG|FmG~FsI`I{DpD_BzAaAt@{@d@w@Z_AVy@L_AHe]Z__@^}XReEDkOJsKJyKHyAAgAIgAKaAUgA[s@[u@c@eFeDaDyBkAq@eAc@cAYeAQcBO{AIqPc@sHOuBKuC]mBY}Bk@yAi@{CeAgBo@eBi@oASmAGwABuANeAXkA`@}Av@{At@yAf@eATiAFeBB}b@u@{CGkAEiAOqA[{@YaAk@k@_@qAqAg@{@OWe@_A_@wAScAWsBo@eFe@{EK}AO}DK}BI{AOkA]gB_AmDiAyEo@wEc@gDa@}CSuAo@sEaAeHi@uBe@gAu@iAiAeBo@}@',
#   'mode': 'driving',
#   'duration': 2219.2,
#   'maneuver': {'bearing_after': 4,
#    'type': 'new name',
#    'modifier': 'straight',
#    'bearing_before': 4,
#    'location': [72.905262, 19.292134]},
#   'ref': 'NH48',
#   'weight': 2219.2,
#   'distance': 52397.7,
#   'name': 'Mumbai Delhi Highway'},
#  {'intersections': [{'out': 1,
#     'location': [72.928519, 19.71031],
#     'bearings': [30, 45, 225],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.933362, 19.71416],
#     'bearings': [45, 225, 240],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 1,
#     'location': [72.935068, 19.715952],
#     'bearings': [15, 30, 210],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 3,
#     'location': [72.930572, 19.723444],
#     'bearings': [45, 150, 225, 330],
#     'entry': [True, False, True, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.93004, 19.724154],
#     'bearings': [150, 180, 330],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.926744, 19.728295],
#     'bearings': [45, 135, 315],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 3,
#     'location': [72.925913, 19.728939],
#     'bearings': [30, 135, 195, 315],
#     'entry': [True, False, True, True],
#     'in': 1},
#    {'out': 3,
#     'location': [72.917532, 19.736848],
#     'bearings': [45, 150, 225, 315],
#     'entry': [True, False, True, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.914912, 19.765251],
#     'bearings': [168, 340, 349],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.913722, 19.772324],
#     'bearings': [165, 195, 345],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.913526, 19.780782],
#     'bearings': [4, 184, 356],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.913374, 19.78275],
#     'bearings': [165, 195, 345],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.912026, 19.790227],
#     'bearings': [0, 180, 300],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.911951, 19.7916],
#     'bearings': [0, 180, 240],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 1,
#     'location': [72.940794, 19.820164],
#     'bearings': [90, 105, 285],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.942621, 19.820758],
#     'bearings': [45, 225, 240],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 1,
#     'location': [72.951075, 19.831534],
#     'bearings': [0, 15, 195],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 2,
#     'location': [72.948791, 19.845245],
#     'bearings': [75, 165, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.948594, 19.846028],
#     'bearings': [165, 330, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.948183, 19.849321],
#     'bearings': [0, 90, 180],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 3,
#     'location': [72.940166, 19.91015],
#     'bearings': [105, 165, 300, 345],
#     'entry': [True, False, True, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.939421, 19.911932],
#     'bearings': [60, 165, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.939391, 19.912003],
#     'bearings': [165, 210, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.937669, 19.916191],
#     'bearings': [75, 165, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.937057, 19.917706],
#     'bearings': [75, 165, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.934317, 19.926518],
#     'bearings': [0, 90, 165],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [72.934907, 19.93732],
#     'bearings': [0, 15, 195],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 2,
#     'location': [72.934658, 19.94543],
#     'bearings': [165, 180, 345],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.934652, 19.945458],
#     'bearings': [165, 255, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.934352, 19.946888],
#     'bearings': [75, 165, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.933994, 19.948612],
#     'bearings': [165, 270, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.931939, 19.96743],
#     'bearings': [0, 90, 180],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.931703, 19.969926],
#     'bearings': [0, 120, 180],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 2,
#     'location': [72.929258, 19.979189],
#     'bearings': [90, 165, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.925165, 20.018007],
#     'bearings': [165, 330, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.924805, 20.019691],
#     'bearings': [75, 165, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.9244, 20.02159],
#     'bearings': [165, 195, 345],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.923663, 20.025041],
#     'bearings': [165, 255, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.923376, 20.026653],
#     'bearings': [165, 330, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.922747, 20.029548],
#     'bearings': [165, 195, 345],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.920073, 20.042123],
#     'bearings': [165, 270, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.918931, 20.047312],
#     'bearings': [165, 330, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.917817, 20.052656],
#     'bearings': [165, 195, 345],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.91486, 20.071677],
#     'bearings': [0, 75, 180, 270],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 0,
#     'location': [72.914834, 20.07193],
#     'bearings': [0, 180, 330],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 3,
#     'location': [72.91311, 20.085641],
#     'bearings': [0, 180, 195, 345],
#     'entry': [True, False, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.912798, 20.088242],
#     'bearings': [0, 180, 195],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.913157, 20.099981],
#     'bearings': [15, 195, 270],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 1,
#     'location': [72.914372, 20.103386],
#     'bearings': [0, 15, 195],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [72.915109, 20.105451],
#     'bearings': [15, 195, 210],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.916471, 20.109897],
#     'bearings': [7, 187, 354],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.91668, 20.114835],
#     'bearings': [0, 180, 210],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.916683, 20.114966],
#     'bearings': [1, 181, 355],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [72.916984, 20.130735],
#     'bearings': [0, 180, 195],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 0,
#     'location': [72.917059, 20.131412],
#     'bearings': [0, 180, 270],
#     'entry': [True, False, True],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'mthwBgzb|LaB{ByA{BuH}JcF_Hk@q@eBuBiA{Am@m@cAm@s@_@OGm@U}AWiAEy@?uAJkATkAb@eBx@eB`A[TeAj@sApA{@`AgAbB_AtAw@bAgAdAkF~Di@Z{BzAQLyA`AcFpDoKrHsAhA[`@_CdDoObSaBrBsKxK}LdLiBrAWRwChA{Dr@iFj@mCFqDHgBDyTh@e[L{JZix@rDyIZ{GM}BJwARqH|@}Kz@uTrByGl@sUh@cGMiLc@{BIyCFsB`@gAR}Cx@_Dt@gGz@oD\\yDR_NXqGNeEHkB?wBMkFm@yBBaFp@gBQuAm@kA_Au@mAYw@Oq@IuAHcD?gAGoAqAoFy@sGq@iAmAyA_TcMkFaGiJcO{AaBmHkG_KaKcAk@eD}AqA_Aw@mBk@kCg@sAsQsU_AeAeAy@_C{@_BQaF[uBg@kAq@{@w@o@m@o@mAc@qAc@mBGaCp@yHJwAKcBu@aBaAoAoAcBaJsLsHgMiAuAgBoA}EaCkH}CyEkAcDo@uHqBSGaGiAkC?}DToHn@qVxDia@rG{Cf@wB\\qDR_IXg@DkG`@uFf@uBNqANaDXsCf@cDfAyDpAsBj@kCXcGf@gDV_KS{EKwDKeB@{BP{ALw]dD}P`BgDLgC@{BGuEIeFGuGI_BB_AHeDd@iBHsA?cAE{@K_BW}A[}@KuA@_AFm@HkEdAkQ`E_LpCk@JkARkWxFuB^}ANwAHaAB_CDeLPyC\\uCh@kX|DiAPyANcDAaCGqH{AuEaA{@?W@aD`AsC~@m@RMDkK`DyLtDoHxBoIfCkExAmBn@sCt@gFr@mNzBmFj@eUbAaHZiCBoDCyAKqAOiF}@qCk@qCg@sCg@o@K}A[{Ba@cB[eASsBKoCC}CN_CZ_SnCE@m@HoFp@wIfAcKnAyDZubBlHsNn@oT~@eBLaDh@gLfDC?yBz@}IjCod@bNoIxCkBd@}BPuDWiHy@yIkAkgA}NeCMoDN}Ch@ch@fNmCr@cFz@yTrCeFp@iBT{JpAqTrCeALa@DqAHgCXqAPaFr@oGv@k]jEeo@jIa]pEu@JUDy@LYDy]hEeBTkBVySnCwO|AwiArHq@DwADaBLeBLqFZuG^qAHsBPwALor@nEgO|@}Mt@mEVwIj@}EVyFN{CQiC[aBWgMcDiTqF{KsCwNsD_IsAaAG_COuCKwCAmPKY?q@AqGEmTC_HCyHIuDAgP@eLM}EI}@AeBGeCO_P{@aH_@[?',
#   'mode': 'driving',
#   'duration': 2173.9,
#   'maneuver': {'bearing_after': 49,
#    'type': 'fork',
#    'modifier': 'slight right',
#    'bearing_before': 49,
#    'location': [72.928519, 19.71031]},
#   'ref': 'NH48',
#   'weight': 2173.9,
#   'distance': 51307.4,
#   'name': 'Mumbai Delhi Highway'},
#  {'intersections': [{'out': 3,
#     'location': [72.917524, 20.135716],
#     'bearings': [2, 185, 186, 358],
#     'entry': [True, False, True, True],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'gw{yBou`|LuFD',
#   'mode': 'driving',
#   'duration': 5.8,
#   'maneuver': {'bearing_after': 357,
#    'type': 'fork',
#    'modifier': 'slight left',
#    'bearing_before': 4,
#    'location': [72.917524, 20.135716]},
#   'weight': 5.8,
#   'distance': 137.3,
#   'name': 'Girgaon Dolharpada Talasari'},
#  {'intersections': [{'out': 2,
#     'location': [72.917487, 20.13695],
#     'bearings': [175, 178, 350],
#     'entry': [False, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.913527, 20.154535],
#     'bearings': [143, 316, 322],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.91002, 20.158452],
#     'bearings': [145, 152, 325],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.901203, 20.171715],
#     'bearings': [135, 225, 315],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.895298, 20.179518],
#     'bearings': [150, 240, 330],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.890921, 20.188563],
#     'bearings': [165, 330, 345],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.889662, 20.195059],
#     'bearings': [165, 195, 345],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 0,
#     'location': [72.889178, 20.205339],
#     'bearings': [0, 180, 345],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 2,
#     'location': [72.889072, 20.207928],
#     'bearings': [165, 195, 345],
#     'entry': [False, False, True],
#     'in': 0},
#    {'out': 2,
#     'location': [72.883507, 20.211325],
#     'bearings': [30, 120, 300],
# ...
#   'mode': 'driving',
#   'duration': 219.3,
#   'maneuver': {'bearing_after': 71,
#    'type': 'new name',
#    'modifier': 'straight',
#    'bearing_before': 71,
#    'location': [76.894872, 28.676138]},
#   'ref': 'SH22',
#   'weight': 219.3,
#   'distance': 3960.6,
#   'name': ''},
#  {'intersections': [{'out': 0,
#     'location': [76.929989, 28.691707],
#     'bearings': [45, 105, 225, 285],
#     'entry': [True, False, False, True],
#     'in': 2},
#    {'out': 0,
#     'location': [76.930057, 28.691782],
#     'bearings': [105, 225, 285],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 1,
#     'location': [76.931297, 28.691436],
#     'bearings': [0, 105, 285],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [76.931487, 28.691383],
#     'bearings': [15, 105, 195, 285],
#     'entry': [True, True, True, False],
#     'in': 3},
#    {'out': 1,
#     'location': [76.93277, 28.691087],
#     'bearings': [30, 105, 285],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [76.933665, 28.690957],
#     'bearings': [30, 105, 285],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [76.936304, 28.69067],
#     'bearings': [30, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [76.945694, 28.689812],
#     'bearings': [75, 90, 270],
#     'entry': [True, True, False],
#     'in': 2}],
#   'driving_side': 'right',
#   'geometry': 'ezbnDmkptMMMbAwFJe@r@wEDg@PeBFmAf@iIPcEzA}]p@gPRaFHmBPgE@G',
#   'mode': 'driving',
#   'duration': 92.3,
#   'maneuver': {'bearing_after': 37,
#    'type': 'end of road',
#    'modifier': 'right',
#    'bearing_before': 37,
#    'location': [76.929989, 28.691707]},
#   'weight': 92.3,
#   'distance': 1657.8,
#   'name': ''},
#  {'intersections': [{'out': 0,
#     'location': [76.94673, 28.689706],
#     'bearings': [90, 210, 270],
#     'entry': [True, False, False],
#     'in': 2},
#    {'out': 0,
#     'location': [76.947055, 28.689692],
#     'bearings': [90, 270],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 1,
#     'location': [76.95136, 28.689279],
#     'bearings': [0, 90, 180, 270],
#     'entry': [True, True, True, False],
#     'in': 3},
#    {'out': 0,
#     'location': [76.960142, 28.688467],
#     'bearings': [90, 285, 300],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 1,
#     'location': [76.960264, 28.688461],
#     'bearings': [30, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [76.962365, 28.688217],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [76.966533, 28.687837],
#     'bearings': [15, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [76.969252, 28.687593],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [76.974197, 28.687152],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [76.976692, 28.686939],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [76.994652, 28.685376],
#     'bearings': [90, 180, 270, 345],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 1,
#     'location': [76.998365, 28.685069],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [76.998854, 28.68503],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.000485, 28.684894],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2}],
#   'driving_side': 'right',
#   'geometry': 'umbnDatstM?QBo@FyAhAaWJ}B|Am`@n@qNF}@@W@}@ZoDPwDFkAbAsVZmHTqFfAqXNkDPcEVmH^iKBy@HeBrA{[TiGbA_Xp@{Oh@{NFcAt@cT@MDqA?ILmDLoCBm@',
#   'mode': 'driving',
#   'duration': 224.2,
#   'maneuver': {'bearing_after': 91,
#    'type': 'new name',
#    'modifier': 'straight',
#    'bearing_before': 97,
#    'location': [76.94673, 28.689706]},
#   'ref': 'NH10',
#   'weight': 224.2,
#   'distance': 5295.7,
#   'name': ''},
#  {'intersections': [{'out': 0,
#     'location': [77.000718, 28.684874],
#     'bearings': [90, 270],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 1,
#     'location': [77.010053, 28.684052],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [77.026827, 28.682696],
#     'bearings': [95, 276, 277],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 1,
#     'location': [77.027886, 28.682609],
#     'bearings': [0, 90, 180, 270],
#     'entry': [True, True, True, False],
#     'in': 3},
#    {'out': 1,
#     'location': [77.028595, 28.682557],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.030835, 28.682466],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.032561, 28.682448],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.032869, 28.682444],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.034309, 28.682422],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.035509, 28.682403],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.037813, 28.682367],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.038622, 28.682355],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.039491, 28.682343],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.041353, 28.682322],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.045155, 28.682279],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.04662, 28.68227],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.048528, 28.682255],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.052238, 28.682223],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.054065, 28.682214],
#     'bearings': [30, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.055344, 28.682228],
#     'bearings': [30, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.056838, 28.682249],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 2,
#     'location': [77.059785, 28.682245],
#     'bearings': [3, 87, 96, 274],
#     'entry': [True, True, True, False],
#     'in': 3},
#    {'out': 0,
#     'location': [77.071518, 28.682144],
#     'bearings': [95, 267, 276],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 1,
#     'location': [77.073011, 28.682028],
#     'bearings': [0, 105, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.073395, 28.681983],
#     'bearings': [60, 105, 285],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.080809, 28.681117],
#     'bearings': [15, 105, 285],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.082324, 28.680951],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.085476, 28.680609],
#     'bearings': [15, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.089473, 28.680181],
#     'bearings': [0, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.090794, 28.680047],
#     'bearings': [15, 90, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.093846, 28.679727],
#     'bearings': [75, 90, 285],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.094463, 28.679653],
#     'bearings': [15, 105, 195, 285],
#     'entry': [True, True, False, False],
#     'in': 3},
#    {'out': 1,
#     'location': [77.094793, 28.679613],
#     'bearings': [15, 105, 195, 285],
#     'entry': [False, True, True, False],
#     'in': 3},
#    {'out': 0,
#     'location': [77.095389, 28.679541],
#     'bearings': [105, 285, 315],
#     'entry': [True, False, False],
#     'in': 1},
#    {'out': 1,
#     'location': [77.106185, 28.678169],
#     'bearings': [15, 105, 285],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.109861, 28.677707],
#     'bearings': [15, 105, 285],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [77.110827, 28.677586],
#     'bearings': [105, 285, 330],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [77.113945, 28.677207],
#     'bearings': [105, 195, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [77.133519, 28.674684],
#     'bearings': [99, 279, 290],
#     'entry': [True, False, True],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': 'moanDoe~tMbDiy@JgCtCsu@b@_Qf@gO^wJPsE@UFwBNmF@qEBwI?Y@c@B_HBoFDkM@aD@eB@gABsJFyV?O@sG?{C@aFFwU?M@mJ?i@CsECkH?a@CkGCiCFuCHeB@kL?cC@{SFsOBuICmCRyG@OHmA~@gPDw@Du@h@aJt@qMF_AXmFt@_OLwBl@}Kf@_KXgGr@yNJiBJcBBUFaALwBZcFv@uMxDyk@B[zA}UVaEhAeQ@i@F}@zGmaA|Bab@h@_Gl@{Ib@}Gf@wEFkA',
#   'mode': 'driving',
#   'duration': 568,
#   'maneuver': {'bearing_after': 95,
#    'type': 'new name',
#    'modifier': 'straight',
#    'bearing_before': 94,
#    'location': [77.000718, 28.684874]},
#   'ref': 'NH9',
#   'weight': 568,
#   'distance': 13316,
#   'name': 'Rohtak Road'},
#  {'intersections': [{'out': 1,
#     'location': [77.136412, 28.674257],
#     'bearings': [90, 105, 270],
#     'entry': [True, True, False],
#     'in': 2},
#    {'classes': ['tunnel'],
#     'out': 0,
#     'location': [77.139562, 28.673855],
#     'bearings': [105, 270],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 0,
#     'location': [77.140613, 28.673708],
#     'bearings': [105, 285],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 1,
#     'location': [77.143618, 28.67334],
#     'bearings': [0, 90, 270, 285],
#     'entry': [True, True, False, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.149837, 28.672601],
#     'bearings': [15, 105, 285],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.154483, 28.671803],
#     'bearings': [0, 105, 285],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 1,
#     'location': [77.157408, 28.671282],
#     'bearings': [60, 105, 285],
#     'entry': [True, True, False],
#     'in': 2}],
#   'driving_side': 'right',
#   'geometry': 'cm_nDquxuMV{Bv@yN\\qEf@_GZuFDcBJmDR_EnAwRb@uFJuA\\mDZmDp@wGf@uE\\eDJaA|@aJJw@NiAFa@XmCRyBR{AToA',
#   'mode': 'driving',
#   'duration': 131.9,
#   'maneuver': {'bearing_after': 101,
#    'type': 'continue',
#    'modifier': 'straight',
#    'bearing_before': 95,
#    'location': [77.136412, 28.674257]},
#   'weight': 131.9,
#   'distance': 2378.7,
#   'name': 'Rohtak Road'},
#  {'intersections': [{'out': 0,
#     'location': [77.160414, 28.670656],
#     'bearings': [105, 120, 285],
#     'entry': [True, True, False],
#     'in': 2}],
#   'driving_side': 'right',
#   'geometry': 'sv~mDqk}uMl@cDpFoQ',
#   'mode': 'driving',
#   'duration': 26.3,
#   'maneuver': {'bearing_after': 106,
#    'type': 'fork',
#    'modifier': 'slight left',
#    'bearing_before': 106,
#    'location': [77.160414, 28.670656]},
#   'weight': 26.3,
#   'distance': 402.2,
#   'name': 'Rohtak Road'},
#  {'intersections': [{'out': 0,
#     'location': [77.164191, 28.669222],
#     'bearings': [105, 120, 300],
#     'entry': [True, True, False],
#     'in': 2}],
#   'driving_side': 'right',
#   'geometry': 'sm~mDec~uMFeASu@',
#   'mode': 'driving',
#   'duration': 4.7,
#   'maneuver': {'bearing_after': 98,
#    'type': 'turn',
#    'modifier': 'slight left',
#    'bearing_before': 113,
#    'location': [77.164191, 28.669222]},
#   'weight': 4.7,
#   'distance': 62.8,
#   'name': ''},
#  {'intersections': [{'out': 0,
#     'location': [77.164808, 28.669276],
#     'bearings': [15, 30, 195, 240],
#     'entry': [True, True, True, False],
#     'in': 3},
#    {'classes': ['tunnel'],
#     'out': 0,
#     'location': [77.164971, 28.669653],
#     'bearings': [30, 195],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 0,
#     'location': [77.165179, 28.670024],
#     'bearings': [30, 210],
#     'entry': [True, False],
#     'in': 1},
#    {'out': 0,
#     'location': [77.165327, 28.670234],
#     'bearings': [45, 75, 210],
#     'entry': [True, True, False],
#     'in': 2},
#    {'out': 0,
#     'location': [77.166042, 28.670732],
#     'bearings': [60, 240, 255],
#     'entry': [True, False, True],
#     'in': 1},
#    {'out': 0,
#     'location': [77.166295, 28.670857],
#     'bearings': [60, 240, 330],
#     'entry': [True, False, True],
#     'in': 1}],
#   'driving_side': 'right',
#   'geometry': '_n~mDag~uMiA_@iAi@i@]e@e@c@u@Yq@Ys@ISo@uAkBeEgBmEy@yBCU',
#   'mode': 'driving',
#   'duration': 44.8,
#   'maneuver': {'bearing_after': 19,
#    'type': 'fork',
#    'modifier': 'slight left',
#    'bearing_before': 66,
#    'location': [77.164808, 28.669276]},
#   'weight': 44.8,
#   'distance': 606.4,
#   'name': ''},
#  {'intersections': [{'out': 3,
#     'location': [77.169572, 28.672522],
#     'bearings': [75, 165, 255, 345],
#     'entry': [True, True, False, True],
#     'in': 2},
#    {'out': 2,
#     'location': [77.167772, 28.676101],
#     'bearings': [150, 225, 330],
#     'entry': [False, True, True],
#     'in': 0}],
#   'driving_side': 'right',
#   'geometry': 'gb_nDyd_vMi@JaAb@q@`@_GpBcEjB_Br@IBkEvBkE`B',
#   'mode': 'driving',
#   'duration': 51.3,
#   'maneuver': {'bearing_after': 344,
#    'type': 'turn',
#    'modifier': 'left',
#    'bearing_before': 73,
#    'location': [77.169572, 28.672522]},
#   'ref': 'Locak_knowledge',
#   'weight': 51.3,
#   'distance': 686.8,
#   'name': 'Maharaja Nahar singh Marg'},
#  {'intersections': [{'out': 1,
#     'location': [77.166681, 28.678142],
#     'bearings': [150, 240, 330],
#     'entry': [False, True, True],
#     'in': 0},
#    {'out': 1,
#     'location': [77.166152, 28.677825],
#     'bearings': [60, 240, 315],
#     'entry': [False, True, False],
#     'in': 0}],
#   'driving_side': 'right',
#   'geometry': 'ke`nDwr~uM|@hBjAtBHN',
#   'mode': 'driving',
#   'duration': 25.8,
#   'maneuver': {'bearing_after': 234,
#    'type': 'turn',
#    'modifier': 'left',
#    'bearing_before': 336,
#    'location': [77.166681, 28.678142]},
#   'weight': 25.8,
#   'distance': 143.1,
#   'name': ''},
#  {'intersections': [{'out': 1,
#     'location': [77.165482, 28.677402],
#     'bearings': [60, 150, 240, 330],
#     'entry': [False, True, True, True],
#     'in': 0}],
#   'driving_side': 'right',
#   'geometry': 'w``nDgk~uMd@]',
#   'mode': 'driving',
#   'duration': 9.2,
#   'maneuver': {'bearing_after': 144,
#    'type': 'turn',
#    'modifier': 'left',
#    'bearing_before': 233,
#    'location': [77.165482, 28.677402]},
#   'weight': 9.2,
#   'distance': 26.1,
#   'name': ''},
#  {'intersections': [{'out': 0,
#     'location': [77.165633, 28.677208],
#     'bearings': [60, 150, 330],
#     'entry': [True, True, False],
#     'in': 2}],
#   'driving_side': 'right',
#   'geometry': 'q_`nDel~uMsAkC',
#   'mode': 'driving',
#   'duration': 11.9,
#   'maneuver': {'bearing_after': 54,
#    'type': 'turn',
#    'modifier': 'left',
#    'bearing_before': 144,
#    'location': [77.165633, 28.677208]},
#   'weight': 11.9,
#   'distance': 83.1,
#   'name': ''},
#  {'intersections': [{'in': 0,
#     'entry': [True],
#     'bearings': [235],
#     'location': [77.166334, 28.677633]}],
#   'driving_side': 'right',
#   'geometry': 'eb`nDqp~uM',
#   'mode': 'driving',
#   'duration': 0,
#   'maneuver': {'bearing_after': 0,
#    'type': 'arrive',
#    'modifier': 'left',
#    'bearing_before': 55,
#    'location': [77.166334, 28.677633]},
#   'weight': 0,
#   'distance': 0,
#   'name': ''}]

# %%
def plan_route_oneway(route_json,):
    #assuming only 1 leg
    num_steps=len(route_json['legs'][0]['steps'])
    for i in range(0,num_steps):
        num_intersections=len(route_json['legs'][0]['steps'][i]['intersection'])
        for j in range(0,num_intersections):
            route_json['legs'][0]['steps'][i]['intersection'][j]['location']

# %%
def plan_route(start_lon,start_lat,end_lon,end_lat):
    r = requests.get('http://0.0.0.0:5000/route/v1/driving/'+start_lon+','+start_lat+';'+end_lon+','+end_lat+'?alternatives=3&overview=false&steps=true')
    route_data=r.json()
    num_routes=len(route_data['routes'])
    for i in range(0,num_routes):
        route_arr=[]
        route_arr.append([])
        route_arr[i]+plan_route_oneway(route_data['routes'][i],prev_lon,prev_lat,route_arr,i)
